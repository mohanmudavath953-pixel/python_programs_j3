# %% [markdown]
# #methods or functionin tuplesprint(dir(tuple))

# %%
a=(10,20,30,40,50,10,10,10,10,)
print(a.count(10))
print(a.count(10+20))
# Out:
# 5
# 1

# %%
#index()
a=(10,20,30,40,50,)
print(a.index(30))
# Out:
# 2

# %%
#intersection
a={1,2,3,4,5}
b={3,4,5,6,7,8}
c=a.intersection(b)
print(c)
# Out:
# {3, 4, 5}

# %%
#discard
a={10,20,30,40,50,60,}
print(a)
a.discard(40)
print(a)
# Out:
# {50, 20, 40, 10, 60, 30}
# {50, 20, 10, 60, 30}
